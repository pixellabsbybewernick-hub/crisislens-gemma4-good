# %% [markdown]
# # CrisisLens Kaggle Demo
#
# This notebook demonstrates the core CrisisLens workflow without launching Streamlit.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()))
from gemma_client import analyze_crisis, route_incident

field_note = 'Bridge blocked after heavy flooding. Around 40 people are isolated near the school. No clean water since yesterday. Road access unknown.'
result = analyze_crisis(image_bytes=None, field_note=field_note, language='English', backend_mode='demo fallback only')
result.report

# %%
route_incident(result.report)
